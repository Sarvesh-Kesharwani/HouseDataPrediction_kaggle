# %%
# Out:
# 3.6.2

# %%
# importing required libs at a time
# "import matplotlib.pyplot as plt" OR "from matplotlib import pyplot as plt",
# i prefer first method, since it is shorter ie, "import matplotlib.pyplot as plt"
import matplotlib.pyplot as plt

#checking version of matplotlib library, u can't check version of a module ex: pyplot specificly
import matplotlib
print(matplotlib.__version__)

import numpy as np

#preparing x, y dataset
x = np.array([1, 2])
y = np.array([2, 4])
# Out:
# 3.6.2

# %%
#ploting the graph internally and then showing it on screen
plt.plot(x, y)
plt.show()

# %%
# ploting the graph internally w/o line, just points only 
# and then showing it on screen
plt.plot(x, y, 'o')
plt.show()

# %%
# ploting the graph internally with multiple points, just points only 
# and then showing it on screen

x = np.array([1,2,5,8,2,3])
y = np.array([0,5,3,2,6,7])
plt.plot(x, y)
plt.show()

# %%
# ploting the graph internally without x-dataPoints, just points only 
# and then showing it on screen

y = np.array([0,5,3,2,6,7])
plt.plot(y)
plt.show()
# picks sequential x-datapoints from x-axis ex: 0,1,2,3,4,5....and so on

# %%
#this is an exmple of panda's API which i am never gonna use in practicle life
# becoz practical life me we import the dataset from relational databases and don't prepare theme in dictionary
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)

# %% [markdown]
# # plt ke last layer nodes for ML as TOP

# %%
import pandas as pd
data = pd.read_csv("HousePrice_SampleData.csv")

import matplotlib.pyplot as plt
# display(data)
# display(data["MSSubClass"].astype(int))

plt.hist(data["MSSubClass"].astype(int),4)
plt.show()

# %%
# data.info()
plt.hist(data["LotArea"].astype(int))
# Out:
# (array([1.423e+03, 2.400e+01, 8.000e+00, 1.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([  1300. ,  22694.5,  44089. ,  65483.5,  86878. , 108272.5,
#         129667. , 151061.5, 172456. , 193850.5, 215245. ]),
#  <BarContainer object of 10 artists>)

# %%
# display(data.info())
plt.scatter(data['MSSubClass'],data['LotArea'])

# %%
# https://www.w3schools.com/python/python_ml_linear_regression.asp
# a good tehchnique
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
# axes == subplot
# and each subplot is plotted inside a fig
# if you want to plot a single plot, then just use plt.plot()

fig = plt.figure()
x=0
y=0
for i in data.columns:
    for j in data.columns:
        # plt.plot(data[i], data[j])
        x=x+0.5
        fig.add_axes(rect=[x,y,1,1])
        
plt.show()
