# %% [markdown]
# ![chrome_k6nU7D1yfE.png](attachment:chrome_k6nU7D1yfE.png)
# Not a Competition

# %% [markdown]
# https://www.kaggle.com/code/kmalit/bank-customer-churn-prediction/notebook
