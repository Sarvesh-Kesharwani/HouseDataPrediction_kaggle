# %%
import pandas as pd
data = pd.read_csv('online_shoppers_intention.csv')
display(data)

# %%
data.isnull()

# %%
help(isnull())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 help(isnull())
#
# NameError: name 'isnull' is not defined

# %% [markdown]
# # HighValued_Customer_Clustring Problem Concrete Project (Ecommerce Domain)

# %% [markdown]
# ![chrome_lCBL9vwmcw.png](attachment:chrome_lCBL9vwmcw.png)

# %% [markdown]
# # https://www.learnbay-lms.com/courses/take/lb-dsc-6thmarch-wknd-2022/lessons/42276938-e-commerce-analytics-02-29th-january-2023-sunday-8-30-to-10-30pm-ist

# %%
# pipeline for data prepration
    # pipeline for data cleansing
        # interchangable[
        # dropping duplications
        # imputing missing values
        # ]
        #fixing dType issues
        
# so basically there are 2 problems we detect by doing the df.describe() fun ie, 
# 1) missing value problem, and 2) wrong dtype problem

# %% [markdown]
# ![chrome_rXZX2agsU3.png](attachment:chrome_rXZX2agsU3.png)

# %% [markdown]
# ![chrome_vd9JImifkW.png](attachment:chrome_vd9JImifkW.png)

# %% [markdown]
# # Data Cleansing

# %%
# put all logicbot's module codes into learnbay's domain projects, mix it to make logicbot modules alive,
# and this will complete yr ecommerce project and ppt also

# %% [markdown]
# # code and comments in code_Block is for me as a dataScientist to understand that which abstract concept
# # is being implemented and using what code
#
# # whereas the display section is completly for the customer/stakeholder/interviewer for displaying
# # him the insights which i am getting from data and if i am doing smth in a code_block_2 then what was the insight i got from code_block_1, based on which i decided to that.
# # step by step based on (start->insight->action on data->insight->aod->......)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
from pandas import read_csv
data = read_csv('E-com_Data.csv')
display(data)
# Out:
#         CustomerID Item Code  InvoieNo Date of purchase  Quantity        Time  \
# 0           4355.0     15734  398177.0       29-10-2017       6.0  3:36:00 PM
# 1           4352.0     14616  394422.0       05-10-2017       2.0  2:53:00 PM
# 2           4352.0     14614  394422.0       12-10-2017       2.0  2:53:00 PM
# 3           4352.0    85014B  388633.0       22-08-2017       3.0  2:47:00 PM
# 4           4352.0     15364  394422.0       10-10-2017       2.0  2:53:00 PM
# ...            ...       ...       ...              ...       ...         ...
# 541111         NaN       NaN       NaN              NaN       NaN         NaN
# 541112         NaN       NaN       NaN              NaN       NaN         NaN
# 541113         NaN       NaN       NaN              NaN       NaN         NaN
# 541114         NaN       NaN       NaN              NaN       NaN         NaN
# 541115         NaN       NaN       NaN              NaN       NaN         NaN
#
# ...

# %%
data = data.rename(columns={'InvoieNo': 'Invoice No', 'Date of purchase': 'Date'})
data
# Out:
#         CustomerID Item Code  Invoice No        Date  Quantity        Time  \
# 0           4355.0     15734    398177.0  29-10-2017       6.0  3:36:00 PM
# 1           4352.0     14616    394422.0  05-10-2017       2.0  2:53:00 PM
# 2           4352.0     14614    394422.0  12-10-2017       2.0  2:53:00 PM
# 3           4352.0    85014B    388633.0  22-08-2017       3.0  2:47:00 PM
# 4           4352.0     15364    394422.0  10-10-2017       2.0  2:53:00 PM
# ...            ...       ...         ...         ...       ...         ...
# 541111         NaN       NaN         NaN         NaN       NaN         NaN
# 541112         NaN       NaN         NaN         NaN       NaN         NaN
# 541113         NaN       NaN         NaN         NaN       NaN         NaN
# 541114         NaN       NaN         NaN         NaN       NaN         NaN
# 541115         NaN       NaN         NaN         NaN       NaN         NaN
#
#         price per Unit   Price Shipping Location Cancelled_status  \
# ...

# %% [markdown]
# ![Code_EANuKzs6GW.png](attachment:Code_EANuKzs6GW.png)

# %%
# data.shape - anyways data.info() covers data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541116 entries, 0 to 541115
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         404189 non-null  float64
#  1   Item Code          537979 non-null  object
#  2   Invoice No         537979 non-null  float64
#  3   Date               537979 non-null  object
#  4   Quantity           537979 non-null  float64
#  5   Time               537979 non-null  object
#  6   price per Unit     537979 non-null  float64
#  7   Price              537979 non-null  float64
#  8   Shipping Location  537979 non-null  object
#  9   Cancelled_status   8345 non-null    object
#  10  Reason of return   3 non-null       object
#  11  Sold as set        0 non-null       float64
# dtypes: float64(6), object(6)
# memory usage: 49.5+ MB

# %%
# no of rows in data originally
rows1 = data.shape[0]
print(f'no of rows in data originally: {rows1}\n')

# percentage of null rows in data
display('Percentage of missing rows in each column:-', data.isnull().sum()/len(data)*100)
# Out:
# no of rows in data originally: 541116
# 'Percentage of missing rows in each column:-'
# CustomerID            25.304556
# Item Code              0.579728
# Invoice No             0.579728
# Date                   0.579728
# Quantity               0.579728
# Time                   0.579728
# price per Unit         0.579728
# Price                  0.579728
# Shipping Location      0.579728
# Cancelled_status      98.457817
# Reason of return      99.999446
# Sold as set          100.000000
# dtype: float64

# %%
# pigenhole principle: ie, one customer has multiple transactions
display('no of pigeons/transactions:' ,data['CustomerID'].shape[0])
display('no of holes/customers:' ,data['CustomerID'].nunique())
# Out:
# 'no of pigeons/transactions:'
# 541116
# 'no of holes/customers:'
# 4349

# %%
# duplicate rows analysis
print(f'weather a row is duplicate or not : \n{data.duplicated()}\n')
print(f'we have {data.duplicated().sum()} no of duplicate rows in data.\n')

# column on left is the index column which is there in all dataframes, It is not considered as column
# thus this below table has only one column, which is legal to pass in loc function
# Out:
# weather a row is duplicate or not :
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541111     True
# 541112     True
# 541113     True
# 541114     True
# 541115     True
# Length: 541116, dtype: bool
#
# we have 3145 no of duplicate rows in data.

# %%
# since loc function takes index nums(0,1....n) we can pass boolean series and pick specified rows. 
# note: iloc is column wise accessor and loc is row wise accessor
data.loc[data.duplicated()]

# we don't see any 2 rows duplicate of each other in below table, becoz these selected rows are 2nd or 3rd....
# copies of 1st copy.
# Out:
#         CustomerID Item Code  Invoice No        Date  Quantity         Time  \
# 61202       4043.0     15819    403353.0  02-12-2017       1.0   2:07:00 PM
# 70587       3984.0     15422    405579.0  09-12-2017      24.0   2:09:00 PM
# 84823       3828.0     14519    398139.0  31-10-2017       1.0   2:04:00 PM
# 120521      3384.0     15121    380588.0  11-06-2017       1.0  11:37:00 AM
# 182786      2607.0     15660    393225.0  30-09-2017       1.0  12:31:00 PM
# ...            ...       ...         ...         ...       ...          ...
# 541111         NaN       NaN         NaN         NaN       NaN          NaN
# 541112         NaN       NaN         NaN         NaN       NaN          NaN
# 541113         NaN       NaN         NaN         NaN       NaN          NaN
# 541114         NaN       NaN         NaN         NaN       NaN          NaN
# 541115         NaN       NaN         NaN         NaN       NaN          NaN
#
# ...

# %%
data = data.drop_duplicates(ignore_index=True)
print(f'now of duplicate rows now: ' ,data.duplicated().sum(), '\n')
print(f'now we have only {data.shape[0]} no of rows left after droping duplicates.\n')
display(data.info())
# Out:
# now of duplicate rows now:  0
#
# now we have only 537971 no of rows left after droping duplicates.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537971 entries, 0 to 537970
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         404181 non-null  float64
#  1   Item Code          537970 non-null  object
#  2   Invoice No         537970 non-null  float64
#  3   Date               537970 non-null  object
#  4   Quantity           537970 non-null  float64
#  5   Time               537970 non-null  object
#  6   price per Unit     537970 non-null  float64
#  7   Price              537970 non-null  float64
#  8   Shipping Location  537970 non-null  object
#  9   Cancelled_status   8345 non-null    object
#  10  Reason of return   3 non-null       object
#  11  Sold as set        0 non-null       float64
# dtypes: float64(6), object(6)
# memory usage: 49.3+ MB
# None

# %% [markdown]
# # Data Modeling

# %%
# top == ecomerce RFM clustring like concrete projects

# %%
# XG-boost
# https://www.logikbot.com/courses/take/applied-statistics-for-machine-learning-engineers/lessons/16730702-course-introduction
